# %%
from Functions import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/TweetsOriginal.csv', encoding = 'ISO-8859-1')
x_train, x_test, y_train, y_test = clean_split(2, df)
print(x_train.shape, x_test.shape) 
print(y_train.shape, y_test.shape)
# Out:
# Original Value Counts
# 1.0    2978
# 0.0     570
# Name: Emotion_New, dtype: int64
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Final Resampled Value Counts
# 1.0    600
# 0.0    570
# Name: Emotion_New, dtype: int64
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Finished Pickling
# (994, 5000) (176, 5000)
# (994,) (176,)

# %% [markdown]
# ### Resampling
# - 0 = negative
# - 1 = Positive
# - 2 = neutral

# %% [markdown]
# ### Neural Network

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten 
from keras.layers import Conv1D, GlobalMaxPooling1D, BatchNormalization, Embedding, LSTM
from keras import regularizers
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
# Out:
# Using plaidml.keras.backend backend.

# %%
def get_nn_model(x, model_type, act):
    model = Sequential()

    if model_type == 'embedding':
        model.add(Embedding(5000, 100, input_length = len(x[0]), trainable = False, name = 'Input'))
        model.add(Flatten())
        model.add(Dense(32, activation = act))
        
    elif model_type == 'normal': 
        model.add(Dense(32, activation = act, input_shape = x[0].shape, name = 'Input'))
        model.add(Dense(64, activation = act))
        model.add(Dense(128, activation = act))

        
    elif model_type == 'cnn': 
        model.add(Embedding(5000, 100, input_length = len(x[0]), trainable = False,  name = 'Input'))
        model.add(Conv1D(128, 5, activation = act))
        model.add(GlobalMaxPooling1D())
        model.add(Dense(64, activation = act))
    
    elif model_type == 'LSTM': 
        model.add(Embedding(5000, 100, input_length = len(x[0]), trainable = False,  name = 'Input'))
        model.add(LSTM(128, activation = act))


    model.add(Dense(1, activation = 'sigmoid', name = 'OutputLayer'))
    model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
    return model

# %% [markdown]
# ### Normal Model

# %%
#normal
model_type = 'normal'
act = 'sigmoid'
model = get_nn_model(x_train, model_type, act)
print(model.summary())

#cnn
early_stopping = EarlyStopping(monitor='val_loss', verbose = 1, patience=20)
model_checkpoint = ModelCheckpoint(f'../Weights/{model_type.upper()}_{act}-ModelCheckpointWeights.h5', verbose = 1, save_best_only=True,
                                  monitor = 'val_loss')
lr_plat = ReduceLROnPlateau(patience = 3, mode = 'min')

callbacks = [early_stopping, model_checkpoint]
epochs = 100 
batch_size= 32

model_history = model.fit(x_train, y_train, epochs = epochs, batch_size = batch_size, 
                         validation_data = (x_test, y_test), callbacks = callbacks)
# Out:
# INFO:plaidml:Opening device "opencl_amd_ellesmere.0"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (Dense)                (None, 32)                160032
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               8320
# _________________________________________________________________
# OutputLayer (Dense)          (None, 1)                 129
# =================================================================
# Total params: 170,593
# Trainable params: 170,593
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 994 samples, validate on 176 samples
# Epoch 1/100
# 994/994 [==============================] - 5s 5ms/step - loss: 0.6924 - acc: 0.5252 - val_loss: 0.7201 - val_acc: 0.4886
#
# Epoch 00001: val_loss improved from inf to 0.72011, saving model to ../Weights/NORMAL_sigmoid-ModelCheckpointWeights.h5
# Epoch 2/100
# 994/994 [==============================] - 0s 293us/step - loss: 0.7114 - acc: 0.4668 - val_loss: 0.6963 - val_acc: 0.4886
#
# Epoch 00002: val_loss improved from 0.72011 to 0.69633, saving model to ../Weights/NORMAL_sigmoid-ModelCheckpointWeights.h5
# Epoch 3/100
# 994/994 [==============================] - 0s 293us/step - loss: 0.6903 - acc: 0.5191 - val_loss: 0.6927 - val_acc: 0.4886
#
# Epoch 00003: val_loss improved from 0.69633 to 0.69270, saving model to ../Weights/NORMAL_sigmoid-ModelCheckpointWeights.h5
# Epoch 4/100
# 994/994 [==============================] - 0s 293us/step - loss: 0.6871 - acc: 0.5282 - val_loss: 0.6856 - val_acc: 0.5114
#
# Epoch 00004: val_loss improved from 0.69270 to 0.68561, saving model to ../Weights/NORMAL_sigmoid-ModelCheckpointWeights.h5
# Epoch 5/100
# 994/994 [==============================] - 0s 294us/step - loss: 0.6526 - acc: 0.7324 - val_loss: 0.6546 - val_acc: 0.7102
#
# Epoch 00005: val_loss improved from 0.68561 to 0.65461, saving model to ../Weights/NORMAL_sigmoid-ModelCheckpointWeights.h5
# Epoch 6/100
# 994/994 [==============================] - 0s 295us/step - loss: 0.5733 - acc: 0.8581 - val_loss: 0.5993 - val_acc: 0.7273
#
# Epoch 00006: val_loss improved from 0.65461 to 0.59931, saving model to ../Weights/NORMAL_sigmoid-ModelCheckpointWeights.h5
# Epoch 7/100
# 994/994 [==============================] - 0s 298us/step - loss: 0.4443 - acc: 0.8682 - val_loss: 0.5301 - val_acc: 0.7330
#
# Epoch 00007: val_loss improved from 0.59931 to 0.53013, saving model to ../Weights/NORMAL_sigmoid-ModelCheckpointWeights.h5
# Epoch 8/100
# 994/994 [==============================] - 0s 296us/step - loss: 0.2993 - acc: 0.9215 - val_loss: 0.4947 - val_acc: 0.7330
#
# Epoch 00008: val_loss improved from 0.53013 to 0.49474, saving model to ../Weights/NORMAL_sigmoid-ModelCheckpointWeights.h5
# Epoch 9/100
# 994/994 [==============================] - 0s 297us/step - loss: 0.2112 - acc: 0.9437 - val_loss: 0.4828 - val_acc: 0.7386
#
# Epoch 00009: val_loss improved from 0.49474 to 0.48275, saving model to ../Weights/NORMAL_sigmoid-ModelCheckpointWeights.h5
# Epoch 10/100
# 994/994 [==============================] - 0s 294us/step - loss: 0.1543 - acc: 0.9588 - val_loss: 0.4867 - val_acc: 0.7386
#
# Epoch 00010: val_loss did not improve from 0.48275
# Epoch 11/100
# 994/994 [==============================] - 0s 296us/step - loss: 0.1197 - acc: 0.9658 - val_loss: 0.4922 - val_acc: 0.7386
#
# Epoch 00011: val_loss did not improve from 0.48275
# Epoch 12/100
# 994/994 [==============================] - 0s 296us/step - loss: 0.0960 - acc: 0.9718 - val_loss: 0.5030 - val_acc: 0.7386
#
# Epoch 00012: val_loss did not improve from 0.48275
# Epoch 13/100
# 994/994 [==============================] - 0s 306us/step - loss: 0.0805 - acc: 0.9779 - val_loss: 0.5232 - val_acc: 0.7330
#
# Epoch 00013: val_loss did not improve from 0.48275
# Epoch 14/100
# 994/994 [==============================] - 0s 294us/step - loss: 0.0642 - acc: 0.9839 - val_loss: 0.5416 - val_acc: 0.7216
#
# Epoch 00014: val_loss did not improve from 0.48275
# Epoch 15/100
# 994/994 [==============================] - 0s 299us/step - loss: 0.0544 - acc: 0.9889 - val_loss: 0.5599 - val_acc: 0.7330
#
# Epoch 00015: val_loss did not improve from 0.48275
# Epoch 16/100
# 994/994 [==============================] - 0s 300us/step - loss: 0.0474 - acc: 0.9849 - val_loss: 0.5788 - val_acc: 0.7330
#
# Epoch 00016: val_loss did not improve from 0.48275
# Epoch 17/100
# 994/994 [==============================] - 0s 297us/step - loss: 0.0412 - acc: 0.9930 - val_loss: 0.5991 - val_acc: 0.7159
#
# Epoch 00017: val_loss did not improve from 0.48275
# Epoch 18/100
# 994/994 [==============================] - 0s 293us/step - loss: 0.0365 - acc: 0.9920 - val_loss: 0.6253 - val_acc: 0.7216
#
# Epoch 00018: val_loss did not improve from 0.48275
# Epoch 19/100
# 994/994 [==============================] - 0s 296us/step - loss: 0.0347 - acc: 0.9879 - val_loss: 0.6474 - val_acc: 0.7443
#
# Epoch 00019: val_loss did not improve from 0.48275
# Epoch 20/100
# 994/994 [==============================] - 0s 294us/step - loss: 0.0307 - acc: 0.9909 - val_loss: 0.6660 - val_acc: 0.7216
#
# Epoch 00020: val_loss did not improve from 0.48275
# Epoch 21/100
# 994/994 [==============================] - 0s 295us/step - loss: 0.0292 - acc: 0.9920 - val_loss: 0.6742 - val_acc: 0.7216
#
# Epoch 00021: val_loss did not improve from 0.48275
# Epoch 22/100
# 994/994 [==============================] - 0s 309us/step - loss: 0.0266 - acc: 0.9909 - val_loss: 0.6959 - val_acc: 0.7386
#
# Epoch 00022: val_loss did not improve from 0.48275
# Epoch 23/100
# 994/994 [==============================] - 0s 302us/step - loss: 0.0246 - acc: 0.9920 - val_loss: 0.7040 - val_acc: 0.7159
#
# Epoch 00023: val_loss did not improve from 0.48275
# Epoch 24/100
# 994/994 [==============================] - 0s 298us/step - loss: 0.0229 - acc: 0.9940 - val_loss: 0.7252 - val_acc: 0.7330
#
# Epoch 00024: val_loss did not improve from 0.48275
# Epoch 25/100
# 994/994 [==============================] - 0s 307us/step - loss: 0.0232 - acc: 0.9920 - val_loss: 0.7282 - val_acc: 0.7159
#
# Epoch 00025: val_loss did not improve from 0.48275
# Epoch 26/100
# 994/994 [==============================] - 0s 306us/step - loss: 0.0204 - acc: 0.9909 - val_loss: 0.7486 - val_acc: 0.7216
#
# Epoch 00026: val_loss did not improve from 0.48275
# Epoch 27/100
# 994/994 [==============================] - 0s 292us/step - loss: 0.0201 - acc: 0.9930 - val_loss: 0.7567 - val_acc: 0.7216
#
# Epoch 00027: val_loss did not improve from 0.48275
# Epoch 28/100
# 994/994 [==============================] - 0s 299us/step - loss: 0.0195 - acc: 0.9920 - val_loss: 0.7735 - val_acc: 0.7159
#
# Epoch 00028: val_loss did not improve from 0.48275
# Epoch 29/100
# 994/994 [==============================] - 0s 295us/step - loss: 0.0183 - acc: 0.9940 - val_loss: 0.7790 - val_acc: 0.7159
#
# Epoch 00029: val_loss did not improve from 0.48275
# Epoch 00029: early stopping

# %%
plot_loss(model_history, model_type, act)

# %%
model = get_nn_model(x_train, model_type, act)
model.load_weights(f'../Weights/{model_type.upper()}_{act}-ModelCheckpointWeights.h5')

get_roc_auc(model,model_type, act, x_train, y_train, x_test, y_test)
# Out:
# {'F1 Score': 0.753, 'AUC': 0.865, 'ROC': 0.848}

# %%
y_test_prob = model.predict(x_test).ravel() 
y_train_prob = model.predict(x_train).ravel() 

plot_cm(y_train = y_train, y_test = y_test, y_train_prob = y_train_prob,
                      y_test_prob = y_test_prob,classes = ['Negative', 'Positive'], thresholds = [.2, .5,.6], 
        model_type = model_type, act = act)

# %% [markdown]
# ## CNN

# %%
#normal
model_type = 'cnn'
act = 'relu'
model = get_nn_model(x_train, model_type, act)
print(model.summary())

#cnn
early_stopping = EarlyStopping(monitor='val_loss', verbose = 1, patience=5)
model_checkpoint = ModelCheckpoint(f'../Weights/{model_type.upper()}_{act}-ModelCheckpointWeights.h5', verbose = 1, save_best_only=True,
                                  monitor = 'val_loss')
lr_plat = ReduceLROnPlateau(patience = 3, mode = 'min')

callbacks = [early_stopping, model_checkpoint]
epochs = 100 
batch_size= 32

model_history = model.fit(x_train, y_train, epochs = epochs, batch_size = batch_size, 
                         validation_data = (x_test, y_test), callbacks = callbacks)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (Embedding)            (None, 5000, 100)         500000
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 4996, 128)         64128
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                8256
# _________________________________________________________________
# OutputLayer (Dense)          (None, 1)                 65
# =================================================================
# Total params: 572,449
# Trainable params: 72,449
# Non-trainable params: 500,000
# _________________________________________________________________
# None
# Train on 994 samples, validate on 176 samples
# Epoch 1/100
# 256/994 [======>.......................] - ETA: 52s - loss: 0.6951 - acc: 0.4727

# %%
plot_loss(model_history, model_type, act)

# %%
model = get_nn_model(x_train, model_type, act)
model.load_weights(f'../Weights/{model_type.upper()}_{act}-ModelCheckpointWeights.h5')

get_roc_auc(model,model_type, act, x_train, y_train, x_test, y_test)

# %%
y_test_prob = model.predict(x_test).ravel() 
y_train_prob = model.predict(x_train).ravel() 

plot_cm(y_train = y_train, y_test = y_test, y_train_prob = y_train_prob,
                      y_test_prob = y_test_prob,classes = ['Negative', 'Positive'], thresholds = [.2, .5,.6], 
        model_type = model_type, act = act)

# %%
assert False

# %%
##normal
early_stopping = EarlyStopping(monitor='val_loss', verbose = 1, patience=7)
model_checkpoint = ModelCheckpoint(f'models/{model_type.upper()}-ModelCheckpointWeights.h5', verbose = 1, save_best_only=True,
                                  monitor = 'val_loss')
lr_plat = ReduceLROnPlateau(patience = 3, mode = 'min')

callbacks = [early_stopping, model_checkpoint]
epochs = 10 
batch_size= 32

model_history = model.fit(x_train_new, y_train_new, epochs = epochs, batch_size = batch_size, 
                         validation_data = (x_test, y_test), callbacks = callbacks)
